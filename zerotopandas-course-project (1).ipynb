# %% [markdown]
# # Project Title - Happiness Report of World in 2019
#
# It's a project based on the data which I got from https://www.kaggle.com/unsdsn/world-happiness and
# in this project I worked on this dataset to get some idea of the world's happiness report.
# This will give a brief idea about what factors in which the happiness report is being presented and whether the countries scoring great in this report are actually good in all the factors or not and in what factors some of not so happy countries are actually doing good.

# %%
# !pip install jovian opendatasets --upgrade --quiet

# %% [markdown]
# Let's begin by downloading the data, and listing the files within the dataset.

# %%
import opendatasets as od
od.download(dataset_url)
# Out:
# Please provide your Kaggle credentials to download this dataset. Learn more: http://bit.ly/kaggle-creds
# Your Kaggle username:
# Your Kaggle username:
# Your Kaggle username:
# Your Kaggle username:
# Your Kaggle username:
# Your Kaggle username:
# Your Kaggle username:
# Your Kaggle username: amanguptama19c003
# Your Kaggle Key: ········
# ...
# 100%|████████████████████████████████████████████████████████████████████████████▉| 36.0M/36.1M [00:51<00:00, 1.38MB/s]
# 100%|██████████████████████████████████████████████████████████████████████████████| 36.1M/36.1M [00:51<00:00, 739kB/s]

# %% [markdown]
# The dataset has been downloaded and extracted.

# %%
import pandas as pd

# %%
happiness_data_2019=pd.read_csv('2019.csv')

# %%
df = happiness_data_2019

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 156 entries, 0 to 155
# Data columns (total 9 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   Overall rank                  156 non-null    int64
#  1   Country or region             156 non-null    object
#  2   Score                         156 non-null    float64
#  3   GDP per capita                156 non-null    float64
#  4   Social support                156 non-null    float64
#  5   Healthy life expectancy       156 non-null    float64
#  6   Freedom to make life choices  156 non-null    float64
#  7   Generosity                    156 non-null    float64
#  8   Perceptions of corruption     156 non-null    float64
# dtypes: float64(7), int64(1), object(1)
# memory usage: 11.1+ KB

# %%
df.describe()
# Out:
#        Overall rank       Score  GDP per capita  Social support  \
# count    156.000000  156.000000      156.000000      156.000000
# mean      78.500000    5.407096        0.905147        1.208814
# std       45.177428    1.113120        0.398389        0.299191
# min        1.000000    2.853000        0.000000        0.000000
# 25%       39.750000    4.544500        0.602750        1.055750
# 50%       78.500000    5.379500        0.960000        1.271500
# 75%      117.250000    6.184500        1.232500        1.452500
# max      156.000000    7.769000        1.684000        1.624000
#
#        Healthy life expectancy  Freedom to make life choices  Generosity  \
# count               156.000000                    156.000000  156.000000
# mean                  0.725244                      0.392571    0.184846
# std                   0.242124                      0.143289    0.095254
# min                   0.000000                      0.000000    0.000000
# ...

# %% [markdown]
# Let us save and upload our work to Jovian before continuing.

# %%
project_name = "zerotopandas-course-project-starter" # change this (use lowercase letters and hyphens only)

# %%
# !pip install jovian --upgrade -q

# %%
import jovian

# %%
jovian.commit(project=project_name)
# Out:
# [jovian] Attempting to save notebook..
# [jovian] Error: Failed to detect notebook filename. Please provide the correct notebook filename as the "filename" argument to "jovian.commit".

# %%
df.head()
# Out:
#    Overall rank Country or region  Score  GDP per capita  Social support  \
# 0             1           Finland  7.769           1.340           1.587
# 1             2           Denmark  7.600           1.383           1.573
# 2             3            Norway  7.554           1.488           1.582
# 3             4           Iceland  7.494           1.380           1.624
# 4             5       Netherlands  7.488           1.396           1.522
#
#    Healthy life expectancy  Freedom to make life choices  Generosity  \
# 0                    0.986                         0.596       0.153
# 1                    0.996                         0.592       0.252
# 2                    1.028                         0.603       0.271
# 3                    1.026                         0.591       0.354
# 4                    0.999                         0.557       0.322
#
#    Perceptions of corruption
# 0                      0.393
# 1                      0.410
# ...

# %%
df.isnull().sum()
# Out:
# Overall rank                    0
# Country or region               0
# Score                           0
# GDP per capita                  0
# Social support                  0
# Healthy life expectancy         0
# Freedom to make life choices    0
# Generosity                      0
# Perceptions of corruption       0
# dtype: int64

# %%
df.columns
# Out:
# Index(['Overall rank', 'Country or region', 'Score', 'GDP per capita',
#        'Social support', 'Healthy life expectancy',
#        'Freedom to make life choices', 'Generosity',
#        'Perceptions of corruption'],
#       dtype='object')

# %%
df.hist(bins = 30,figsize =(20,20), color = 'r')
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x00000297F374D2C8>,
# ...
#       dtype=object)

# %%
import seaborn as sns
# Out:
# C:\Users\Aman Gupta\Anaconda3\lib\site-packages\statsmodels\tools\_testing.py:19: FutureWarning: pandas.util.testing is deprecated. Use the functions in the public API at pandas.testing instead.
#   import pandas.util.testing as tm

# %%
import matplotlib.pyplot as plt

# %%
corr_matrix = df.corr()
plt.figure(figsize = (12,12))
sns.heatmap(corr_matrix,annot = True)
plt.show()

# %%
import jovian

# %%
jovian.commit()
# Out:
# [jovian] Attempting to save notebook..
# [jovian] Updating notebook "aakashns/zerotopandas-course-project-starter" on https://jovian.ml/
# [jovian] Uploading notebook..
# [jovian] Capturing environment..
# [jovian] Committed successfully! https://jovian.ml/aakashns/zerotopandas-course-project-starter
# 'https://jovian.ml/aakashns/zerotopandas-course-project-starter'

# %% [markdown]
# Let's begin by importing`matplotlib.pyplot` and `seaborn`.

# %%
import seaborn as sns
import matplotlib
import matplotlib.pyplot as plt
# %matplotlib inline

sns.set_style('darkgrid')
matplotlib.rcParams['font.size'] = 14
matplotlib.rcParams['figure.figsize'] = (9, 5)
matplotlib.rcParams['figure.facecolor'] = '#00000000'

# %% [markdown]
# **TODO** - Explore one or more columns by plotting a graph below, and add some explanation about it

# %%
a = df["Freedom to make life choices"]
b = df["GDP per capita"]
c = df["Healthy life expectancy"]

# %%
plt.plot(a,label = 'Freedom to make life choices', color = 'b')
plt.legend()

# %% [raw]
# Here we can see that countries which have scored more on happiness survey of 2019 there people not have that much of freedom of making life choices than many countries which scored poor on happiness index.

# %%
sns.pairplot(df)

# %% [markdown]
# **TODO** - Explore one or more columns by plotting a graph below, and add some explanation about it

# %%
fig, (ax1, ax2, ax3) = plt.subplots(3, 1)
fig.suptitle('Freedom to make life choices,GDP per capita and Healthy life expectancy')

ax1.plot(a, 'o-',color = 'g')
ax1.set_ylabel('Freedom to make life choices')



ax2.plot(b ,'.-',color = 'r')
ax2.set_ylabel('GDP Per Capita')


ax3.plot(c ,'.-',color = 'b')
ax3.set_ylabel('Healthy life expectancy')

ax3.set_xlabel('Countries')
plt.show()

# %% [raw]
# from above plots we can observe that many countries have more GDp per capita but healthy life expectancy is less and also some countires with less GDP per capita have more freedom of making life choices.
# So even some countries are highly ranked but in some factors they are not better than many low ranked countries.

# %%
jovian.commit()
# Out:
# [jovian] Attempting to save notebook..
# [jovian] Updating notebook "aakashns/zerotopandas-course-project-starter" on https://jovian.ml/
# [jovian] Uploading notebook..
# [jovian] Capturing environment..
# [jovian] Committed successfully! https://jovian.ml/aakashns/zerotopandas-course-project-starter
# 'https://jovian.ml/aakashns/zerotopandas-course-project-starter'

# %% [markdown]
# #### Q1: What can you say about the scores and freedom to make life choices of a country?

# %%
freedom_df = df[["Score","Freedom to make life choices"]]

# %%
freedom_df
# Out:
#      Score  Freedom to make life choices
# 0    7.769                         0.596
# 1    7.600                         0.592
# 2    7.554                         0.603
# 3    7.494                         0.591
# 4    7.488                         0.557
# ..     ...                           ...
# 151  3.334                         0.555
# 152  3.231                         0.417
# 153  3.203                         0.000
# 154  3.083                         0.225
# 155  2.853                         0.010
#
# [156 rows x 2 columns]

# %%
sns.pairplot(freedom_df)

# %% [markdown]
# The plots above gives us an idea of how the countries which are highly ranked can have freedom to make life choices a bit lesser in coparison to many not so highly raked counries and surprisingly there are still few contries where there is no freedom to make life choices and that is real concern.

# %% [markdown]
# #### Q2: What can you say about the scores and GDP per capita of a country?

# %%
gdp_df = df[['Score','GDP per capita']]
sns.pairplot(gdp_df)

# %% [markdown]
# Ans: The countries with scores inside 2.5 and 5.0 have GPD per capita pretty much same but the countries which scored larger than 5 are definitely having more GPD per capita.
#     There are few countries which scored more but still their GDP per capita is less in comparison to some of the less scoring countries.
#     You can also find some countries with same GDP per capita even if the difference between their scores is very big.

# %% [markdown]
# #### Q3: What can you say about the scores and Generosity of a country?

# %%
df.head()
# Out:
#    Overall rank Country or region  Score  GDP per capita  Social support  \
# 0             1           Finland  7.769           1.340           1.587
# 1             2           Denmark  7.600           1.383           1.573
# 2             3            Norway  7.554           1.488           1.582
# 3             4           Iceland  7.494           1.380           1.624
# 4             5       Netherlands  7.488           1.396           1.522
#
#    Healthy life expectancy  Freedom to make life choices  Generosity  \
# 0                    0.986                         0.596       0.153
# 1                    0.996                         0.592       0.252
# 2                    1.028                         0.603       0.271
# 3                    1.026                         0.591       0.354
# 4                    0.999                         0.557       0.322
#
#    Perceptions of corruption
# 0                      0.393
# 1                      0.410
# ...

# %%
gen_df = df[["Score","Generosity"]]
sns.pairplot(gen_df)

# %% [markdown]
# Ans: From the plots above we can observe that many counries which have scored high but the generosity of the people is still less than lenty of low scoring countries.
#     Also the generous countires are not the ones which scored highly on the happiness report of 2019.

# %%
df.head()
# Out:
#    Overall rank Country or region  Score  GDP per capita  Social support  \
# 0             1           Finland  7.769           1.340           1.587
# 1             2           Denmark  7.600           1.383           1.573
# 2             3            Norway  7.554           1.488           1.582
# 3             4           Iceland  7.494           1.380           1.624
# 4             5       Netherlands  7.488           1.396           1.522
#
#    Healthy life expectancy  Freedom to make life choices  Generosity  \
# 0                    0.986                         0.596       0.153
# 1                    0.996                         0.592       0.252
# 2                    1.028                         0.603       0.271
# 3                    1.026                         0.591       0.354
# 4                    0.999                         0.557       0.322
#
#    Perceptions of corruption
# 0                      0.393
# 1                      0.410
# ...

# %% [markdown]
# #### Q3: What can you say about the scores and the Perceptions of corruption of a country?

# %%
poc_df = df[["Score","Perceptions of corruption"]]

# %%
sns.pairplot(poc_df)

# %%
df.tail(10)
# Out:
#      Overall rank         Country or region  Score  GDP per capita  \
# 146           147                     Haiti  3.597           0.323
# 147           148                  Botswana  3.488           1.041
# 148           149                     Syria  3.462           0.619
# 149           150                    Malawi  3.410           0.191
# 150           151                     Yemen  3.380           0.287
# 151           152                    Rwanda  3.334           0.359
# 152           153                  Tanzania  3.231           0.476
# 153           154               Afghanistan  3.203           0.350
# 154           155  Central African Republic  3.083           0.026
# 155           156               South Sudan  2.853           0.306
#
#      Social support  Healthy life expectancy  Freedom to make life choices  \
# 146           0.688                    0.449                         0.026
# 147           1.145                    0.538                         0.455
# ...

# %% [markdown]
# Ans : As the score gets bigger surprisingly the Perception of corruptions also getting bigger.
#     Actually the countries which scored least in the happiness report of 2019 are some of those which have very low perception of corruptions.
#     Countries with average scores are more or less having same amount of perception of corruptions.

# %% [markdown]
# Conclusion: The countries which have scored highly on the happiness report actually their factors does not reflect the results totally in some factors countries are scoring better but still they are not scoring high due to some other factor.
#     So from this we can say that many countries are doing good in some factors but overall their happiness score is low because of GDP per capita or/and Social Support or/and freedom to make choices for life.

# %%
jovian.commit()
# Out:
# [jovian] Attempting to save notebook..
# [jovian] Updating notebook "aakashns/zerotopandas-course-project-starter" on https://jovian.ml/
# [jovian] Uploading notebook..
# [jovian] Capturing environment..
# [jovian] Committed successfully! https://jovian.ml/aakashns/zerotopandas-course-project-starter
# 'https://jovian.ml/aakashns/zerotopandas-course-project-starter'

# %%
import jovian

# %%
jovian.commit()
# Out:
# [jovian] Attempting to save notebook..
# [jovian] Updating notebook "aakashns/zerotopandas-course-project-starter" on https://jovian.ml/
# [jovian] Uploading notebook..
# [jovian] Capturing environment..
# [jovian] Committed successfully! https://jovian.ml/aakashns/zerotopandas-course-project-starter
# 'https://jovian.ml/aakashns/zerotopandas-course-project-starter'
